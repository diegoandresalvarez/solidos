# %% [markdown]
# # Viga del ejemplo 2

# %% [markdown]
# Calcule los diagramas de fuerza cortante, momento flector, ángulo de giro y deflexión vertical de la viga mostrada en la figura:
#
# <img src="viga_2.png" width="600">

# %%
from sympy import init_printing, latex, DiracDelta, Piecewise, integrate, symbols, Eq, plot, piecewise_fold, solve, Interval, Rational, sets
from sympy.abc import x

# Para imprimir bonito
init_printing()
from IPython.display import Math                 
def imprimir (texto1, variable, texto2=""):
    return Math(texto1 +  rf'{latex(variable)}' + texto2)

# %% [markdown]
# Se define una función que hace el código más corto y legible, evitando el uso de las [funciones G de Meijerg](https://en.wikipedia.org/wiki/Meijer_G-function):

# %%
integre = lambda f, x : integrate(f, x, meijerg=False)

# %% [markdown]
# Se definen las cargas distribuidas de acuerdo con la tabla 10.3 del `main.pdf`

# %%
# Caso 2: carga puntual 
qpunt = lambda p,a : p*DiracDelta(x-a)

# Caso 5: carga distribuida variable 
qdist = lambda f,a,b : Piecewise((f, (a < x) & (x < b)), (0, True))

# Funcion rectangular: si x>a y x<b retorne 1 sino retorne 0   
rect = lambda a,b : Piecewise((1, (a < x) & (x < b)), (0, True))

# Momento flector
mflec = lambda m,a : -m*DiracDelta(x-a, 1)

# %% [markdown]
# Se define la geometría de la viga y las propiedades del material:

# %%
L = 6               # [m]   Longitud de la viga
b = Rational(1, 10) # [m]   Ancho de la viga
h = Rational(3, 10) # [m]   Altura de la viga
E = 210_000_000     # [kPa] Módulo de elasticidad de la viga
I = (b*h*h*h)/12    # [m⁴]  Momento de inercia en z

# %% [markdown]
# ### Forma 1:

# %% [markdown]
# Se especifica la carga distribuida $q(x)$:

# %%
q = qpunt(-5,1) + qdist(-3*x/2,2,4) + mflec(-8,3.5) + mflec(3,5)

# %% [markdown]
# Se resuelve la ecuación diferencial:

# %%
C1, C2, C3, C4 = symbols('C1 C2 C3 C4')
V = integre(q, x)       + C1
M = integre(V, x)       + C2
t = integre(M/(E*I), x) + C3
v = integre(t, x)       + C4

# %% [markdown]
# ### Forma 2:

# %% [raw]
# # Integral del momento flector
# int_mflec = lambda m,a : -m*DiracDelta(x-a)
#
# # Se descompone el vector de cargas q(x)
# q_sin_momento = qpunt(-5,1) + qdist(-3*x/2,2,4)
# int_momentos  = int_mflec(-8,3.5) + int_mflec(3,5)
#
# # Se resuelve la ecuación diferencial
# C1, C2, C3, C4 = sp.symbols('C1 C2 C3 C4')
# V = integre(q_sin_momento, x) + int_momentos + C1
# M = integre(V, x)                            + C2
# t = integre(M/(E*I), x)                      + C3
# v = integre(t, x)                            + C4

# %% [markdown]
# Se encuentran las constantes de integración que satisfacen las condiciones de frontera:

# %%
sol = solve([ Eq(v.subs(x,0), 0),   # despl vert en apoyo en x=0 es 0
              Eq(M.subs(x,0), 0),   # momento flector     en x=0 es 0
              Eq(v.subs(x,6), 0),   # despl vert en apoyo en x=6 es 0
              Eq(M.subs(x,6), 0) ], # momento flector     en x=6 es 0
              [ C1, C2, C3, C4 ])

# %% [markdown]
# Se reemplaza aquí el valor de las constantes de integración

# %%
V = V.subs(sol)
V2 = V
M = M.subs(sol)
t = t.subs(sol)
v = v.subs(sol)

# %% [markdown]
# Se simplifica lo calculado por sympy:

# %%
def simplificar(VMtv, fracciones=True):    
    var = piecewise_fold(VMtv.rewrite(Piecewise)).as_expr_set_pairs(Interval(0, L))
    tmp = []
    for fun, interv in var:
        if isinstance(interv, sets.sets.Interval | sets.sets.Union):
            if fracciones:
                tmp.append((fun.nsimplify(), interv.as_relational(x)))
            else:
                tmp.append((fun.evalf(),     interv.as_relational(x)))

    return Piecewise(*tmp)

# %%
V = simplificar(V)
M = simplificar(M)
t = simplificar(t, fracciones=False)
v = simplificar(v, fracciones=False)

# %% [markdown]
# ### Se imprimen los resultados

# %%
imprimir("V(x) = ", V)
# Out:
# $\displaystyle V(x) = \begin{cases} \frac{23}{3} & \text{for}\: x \geq 0 \wedge x < 1 \\\frac{8}{3} & \text{for}\: x \leq 2 \wedge x > 1 \\\frac{17}{3} - \frac{3 x^{2}}{4} & \text{for}\: x > 2 \wedge x < 4 \wedge x \neq 3.5 \\- \frac{19}{3} & \text{for}\: x > 4 \wedge x < 6 \wedge x \neq 5 \end{cases}$

# %%
imprimir("M(x) = ", M)
# Out:
# $\displaystyle M(x) = \begin{cases} \frac{23 x}{3} & \text{for}\: x \geq 0 \wedge x < 1 \\\frac{8 x}{3} + 5 & \text{for}\: x \leq 2 \wedge x > 1 \\- \frac{x^{3}}{4} + \frac{17 x}{3} + 1 & \text{for}\: x > 2 \wedge x < 3.5 \\- \frac{x^{3}}{4} + \frac{17 x}{3} + 9 & \text{for}\: x > 3.5 \wedge x < 4 \\41 - \frac{19 x}{3} & \text{for}\: x \geq 4 \wedge x < 5 \\38 - \frac{19 x}{3} & \text{for}\: x \leq 6 \wedge x > 5 \end{cases}$

# %%
imprimir(r"\theta(x) = ", t)
# Out:
# $\displaystyle \theta(x) = \begin{cases} 8.11287477954145 \cdot 10^{-5} x^{2} - 0.000546502057613169 & \text{for}\: x \geq 0 \wedge x < 1 \\2.82186948853616 \cdot 10^{-5} x^{2} + 0.000105820105820106 x - 0.000599412110523221 & \text{for}\: x \leq 2 \wedge x > 1 \\- 1.32275132275132 \cdot 10^{-6} x^{4} + 5.99647266313933 \cdot 10^{-5} x^{2} + 2.11640211640212 \cdot 10^{-5} x - 0.000535920047031158 & \text{for}\: x > 2 \wedge x < 3.5 \\- 1.32275132275132 \cdot 10^{-6} x^{4} + 5.99647266313933 \cdot 10^{-5} x^{2} + 0.00019047619047619 x - 0.00112851263962375 & \text{for}\: x > 3.5 \wedge x < 4 \\- 6.70194003527337 \cdot 10^{-5} x^{2} + 0.000867724867724868 x - 0.00214438565549677 & \text{for}\: x \geq 4 \wedge x < 5 \\- 6.70194003527337 \cdot 10^{-5} x^{2} + 0.000804232804232804 x - 0.00182692533803645 & \text{for}\: x \leq 6 \wedge x > 5 \end{cases}$

# %%
imprimir("v(x) = ", v)
# Out:
# $\displaystyle v(x) = \begin{cases} 2.70429159318048 \cdot 10^{-5} x^{3} - 0.000546502057613169 x & \text{for}\: x \geq 0 \wedge x < 1 \\9.40623162845385 \cdot 10^{-6} x^{3} + 5.29100529100529 \cdot 10^{-5} x^{2} - 0.000599412110523221 x + 1.7636684303351 \cdot 10^{-5} & \text{for}\: x \leq 2 \wedge x > 1 \\- 2.64550264550265 \cdot 10^{-7} x^{5} + 1.99882422104644 \cdot 10^{-5} x^{3} + 1.05820105820106 \cdot 10^{-5} x^{2} - 0.000535920047031158 x - 1.62257495590829 \cdot 10^{-5} & \text{for}\: x > 2 \wedge x < 3.5 \\- 2.64550264550265 \cdot 10^{-7} x^{5} + 1.99882422104644 \cdot 10^{-5} x^{3} + 9.52380952380952 \cdot 10^{-5} x^{2} - 0.00112851263962375 x + 0.00102081128747795 & \text{for}\: x > 3.5 \wedge x < 4 \\- 2.23398001175779 \cdot 10^{-5} x^{3} + 0.000433862433862434 x^{2} - 0.00214438565549677 x + 0.00210440917107584 & \text{for}\: x \geq 4 \wedge x < 5 \\- 2.23398001175779 \cdot 10^{-5} x^{3} + 0.000402116402116402 x^{2} - 0.00182692533803645 x + 0.00131075837742504 & \text{for}\: x \leq 6 \wedge x > 5 \end{cases}$

# %% [markdown]
# Se grafican los resultados

# %%
x_xmin_xmax = (x, 0+0.001, L-0.001)

# %%
plot(V, x_xmin_xmax, xlabel='x [m]', ylabel='V(x) [kN]')

# %%
plot(M, x_xmin_xmax, xlabel='x [m]', ylabel='M(x) [kN-m]')

# %%
plot(t, x_xmin_xmax, xlabel='x [m]', ylabel='θ(x) [rad]')

# %%
plot(v, x_xmin_xmax, xlabel='x [m]', ylabel='v(x) [m]')

# %% [markdown]
# ### Se calculan las reacciones en la viga

# %%
print(f"Fy(x=0) = {float(+V.subs(x, 0))} kN") # Ry en x=0
# Out:
# Fy(x=0) = 7.666666666666667 kN

# %%
print(f"Fy(x=6) = {float(-V.subs(x, 6-0.001))} kN") # Ry en x=6
# Out:
# Fy(x=6) = 6.333333333333333 kN
