# %% [markdown]
# # Viga del ejemplo 2
#
# |Quién | Correo | Fecha | Qué hizo |
# | ---  | ---    | ---   | ---      |
# |Diego Andrés Alvarez Marín | <daalvarez@unal.edu.co> | Febrero 12, 2024  | Conversión de código de Maxima a Python |

# %% [markdown]
# $$
# \newcommand{\dd}{\operatorname{d} \!}
# $$

# %% [markdown]
# Utilizando la **teoría de vigas de Timoshenko-Ehrenfest**, calcule los diagramas de fuerza cortante, momento flector, ángulo de giro y deflexión vertical de la viga mostrada en la figura:
#
# <img src="viga_2.png" width="600">

# %%
from sympy import init_printing, latex, DiracDelta, Piecewise, integrate, symbols, Eq, plot, piecewise_fold, solve, Interval, Rational, sets, diff, expand
from sympy.abc import x

# Para imprimir bonito
init_printing()
from IPython.display import Math                 
def imprimir (texto1, variable, texto2=""):
    return Math(texto1 +  rf'{latex(variable)}' + texto2)

# %% [markdown]
# Se define una función que hace el código más corto y legible, evitando el uso de las [funciones G de Meijerg](https://en.wikipedia.org/wiki/Meijer_G-function):

# %%
integre = lambda f, x : integrate(f, x, meijerg=False)

# %% [markdown]
# Se definen las cargas distribuidas de acuerdo con la tabla 10.3 del `main.pdf`

# %%
# Caso 1: integral del momento flector
int_mflec = lambda m,a : -m*DiracDelta(x-a)

# Caso 2: carga puntual 
qpunt = lambda p,a : p*DiracDelta(x-a)

# Caso 7: carga distribuida variable 
qdist = lambda f,a,b : Piecewise((f, (a < x) & (x < b)), (0, True))

# %% [markdown]
# Se define la geometría de la viga y las propiedades del material:

# %%
L = 6                  # [m]   Longitud de la viga
b = Rational(1, 10)    # [m]   Ancho de la viga
h = Rational(3, 10)    # [m]   Altura de la viga
E = 210_000_000        # [kPa] Módulo de elasticidad
nu = 0.3               #       Coeficiente de Poisson
G = E/(2*(1 + nu))     # [kPa] Módulo de cortante
I = (b*h*h*h)/12       # [m⁴]  Momento de inercia en z  
A = b*h                # [m²]  Área de la sección transversal
alpha = 5/6            #       Factor de corrección del esfuerzo cortante para una sección rectangular

# %% [markdown]
# Se especifica la función de carga $q(x)$:

# %%
q_sin_momento = qpunt(-5,1) + qdist(-3*x/2,2,4)
int_momentos  = int_mflec(-8,3.5) + int_mflec(3,5)

# %% [markdown]
# Se resuelve la ecuación diferencial:

# %%
# Se resuelve la ecuación diferencial
C1, C2, C3, C4 = symbols('C1 C2 C3 C4')
Vsm = integre(q_sin_momento, x)       + C1  # V sin momentos
V   = Vsm + int_momentos                    # V con momentos
M   = integre(V, x)                   + C2
t   = integre(M/(E*I), x)             + C3
v   = integre(t - Vsm/(alpha*G*A), x) + C4

# %% [markdown]
# Se encuentran las constantes de integración que satisfacen las condiciones de frontera:

# %%
sol = solve([ Eq(v.subs(x,0), 0),   # despl vert en apoyo en x=0 es 0
              Eq(M.subs(x,0), 0),   # momento flector     en x=0 es 0
              Eq(v.subs(x,6), 0),   # despl vert en apoyo en x=6 es 0
              Eq(M.subs(x,6), 0) ], # momento flector     en x=6 es 0
              [ C1, C2, C3, C4 ])

# %% [markdown]
# Se reemplaza aquí el valor de las constantes de integración

# %%
V = V.subs(sol)
M = M.subs(sol)
t = t.subs(sol)
v = v.subs(sol)

# %% [markdown]
# Se simplifica lo calculado por sympy:

# %%
def simplificar(VMtv, fracciones=True):
    # rewrite(Piecewise) escribe la función como una por partes
    # as_expr_set_pairs() la expresa como una lista de tuplas
    # la tupla tiene dos elementos (función, dominio de validez)
    var = piecewise_fold(VMtv.rewrite(Piecewise)).as_expr_set_pairs(Interval(0, L))
    tmp = []
    
    # ciclo for sobre cada elemento de la tupla
    for fun, dominio in var:
        # si el dominio es un intervalo o una unión de intervalos
        if isinstance(dominio, sets.sets.Interval | sets.sets.Union):
            if fracciones:
                # intente expresar cualquier número como un fraccionario
                tmp.append((fun.nsimplify(), dominio.as_relational(x)))
            else:
                # intente expresar cualquier fraccionario como un flotante
                tmp.append((fun.evalf(),     dominio.as_relational(x)))
            # as_relational() escribe el dominio como desigualdades y expresiones lógicas

    # exprese la lista de tuplas como una función definida por partes
    return Piecewise(*tmp)

# %%
V    = simplificar(V)
M    = simplificar(M)
t    = simplificar(t, fracciones=False)
v    = simplificar(v, fracciones=False)
dvdx = diff(v,x)

# %% [markdown]
# ### Se imprimen los resultados

# %%
imprimir("V(x) = ", V)
# Out:
# $\displaystyle V(x) = \begin{cases} \frac{23}{3} & \text{for}\: x \geq 0 \wedge x < 1 \\\frac{8}{3} & \text{for}\: x \leq 2 \wedge x > 1 \\\frac{17}{3} - \frac{3 x^{2}}{4} & \text{for}\: x > 2 \wedge x < 4 \wedge x \neq 3.5 \\- \frac{19}{3} & \text{for}\: x > 4 \wedge x < 6 \wedge x \neq 5 \end{cases}$

# %%
imprimir("M(x) = ", M)
# Out:
# $\displaystyle M(x) = \begin{cases} \frac{23 x}{3} & \text{for}\: x \geq 0 \wedge x < 1 \\\frac{8 x}{3} + 5 & \text{for}\: x \leq 2 \wedge x > 1 \\- \frac{x^{3}}{4} + \frac{17 x}{3} + 1 & \text{for}\: x > 2 \wedge x < 3.5 \\- \frac{x^{3}}{4} + \frac{17 x}{3} + 9 & \text{for}\: x > 3.5 \wedge x < 4 \\41 - \frac{19 x}{3} & \text{for}\: x \geq 4 \wedge x < 5 \\38 - \frac{19 x}{3} & \text{for}\: x \leq 6 \wedge x > 5 \end{cases}$

# %%
imprimir(r"\theta(x) = ", t)
# Out:
# $\displaystyle \theta(x) = \begin{cases} 8.11287477954145 \cdot 10^{-5} x^{2} - 0.000546914756025866 & \text{for}\: x \geq 0 \wedge x < 1 \\2.82186948853616 \cdot 10^{-5} x^{2} + 0.000105820105820106 x - 0.000599824808935919 & \text{for}\: x \leq 2 \wedge x > 1 \\- 1.32275132275132 \cdot 10^{-6} x^{4} + 5.99647266313933 \cdot 10^{-5} x^{2} + 2.11640211640212 \cdot 10^{-5} x - 0.000536332745443855 & \text{for}\: x > 2 \wedge x < 3.5 \\- 1.32275132275132 \cdot 10^{-6} x^{4} + 5.99647266313933 \cdot 10^{-5} x^{2} + 0.00019047619047619 x - 0.00112892533803645 & \text{for}\: x > 3.5 \wedge x < 4 \\- 6.70194003527337 \cdot 10^{-5} x^{2} + 0.000867724867724868 x - 0.00214479835390946 & \text{for}\: x \geq 4 \wedge x < 5 \\- 6.70194003527337 \cdot 10^{-5} x^{2} + 0.000804232804232804 x - 0.00182733803644915 & \text{for}\: x \leq 6 \wedge x > 5 \end{cases}$

# %%
imprimir("v(x) = ", v)
# Out:
# $\displaystyle v(x) = \begin{cases} 2.70429159318048 \cdot 10^{-5} x^{3} - 0.000550711581422691 x & \text{for}\: x \geq 0 \wedge x < 1 \\9.40623162845385 \cdot 10^{-6} x^{3} + 5.29100529100529 \cdot 10^{-5} x^{2} - 0.000601145443856554 x + 1.51604938271605 \cdot 10^{-5} & \text{for}\: x \leq 2 \wedge x > 1 \\- 2.64550264550265 \cdot 10^{-7} x^{5} + 2.0112051734274 \cdot 10^{-5} x^{3} + 1.05820105820106 \cdot 10^{-5} x^{2} - 0.000539139094650205 x - 1.67209876543209 \cdot 10^{-5} & \text{for}\: x > 2 \wedge x < 3.5 \\- 2.64550264550265 \cdot 10^{-7} x^{5} + 2.0112051734274 \cdot 10^{-5} x^{3} + 9.52380952380952 \cdot 10^{-5} x^{2} - 0.0011317316872428 x + 0.00102031604938272 & \text{for}\: x > 3.5 \wedge x < 4 \\- 2.23398001175779 \cdot 10^{-5} x^{3} + 0.000433862433862434 x^{2} - 0.00214166184597296 x + 0.00208806631393298 & \text{for}\: x \geq 4 \wedge x < 5 \\- 2.23398001175779 \cdot 10^{-5} x^{3} + 0.000402116402116402 x^{2} - 0.00182420152851264 x + 0.00129441552028219 & \text{for}\: x \leq 6 \wedge x > 5 \end{cases}$

# %%
imprimir(r"\frac{\dd v(x)}{\dd x} = ", dvdx)
# Out:
# $\displaystyle \frac{\dd v(x)}{\dd x} = \begin{cases} 8.11287477954145 \cdot 10^{-5} x^{2} - 0.000550711581422691 & \text{for}\: x \geq 0 \wedge x < 1 \\2.82186948853616 \cdot 10^{-5} x^{2} + 0.000105820105820106 x - 0.000601145443856554 & \text{for}\: x \leq 2 \wedge x > 1 \\- 1.32275132275132 \cdot 10^{-6} x^{4} + 6.03361552028219 \cdot 10^{-5} x^{2} + 2.11640211640212 \cdot 10^{-5} x - 0.000539139094650205 & \text{for}\: x > 2 \wedge x < 3.5 \\- 1.32275132275132 \cdot 10^{-6} x^{4} + 6.03361552028219 \cdot 10^{-5} x^{2} + 0.00019047619047619 x - 0.0011317316872428 & \text{for}\: x > 3.5 \wedge x < 4 \\- 6.70194003527337 \cdot 10^{-5} x^{2} + 0.000867724867724868 x - 0.00214166184597296 & \text{for}\: x \geq 4 \wedge x < 5 \\- 6.70194003527337 \cdot 10^{-5} x^{2} + 0.000804232804232804 x - 0.00182420152851264 & \text{for}\: x \leq 6 \wedge x > 5 \end{cases}$

# %% [markdown]
# ### Se grafican los resultados

# %%
x_xmin_xmax = (x, 0+0.001, L-0.001)

# %%
plot(V, x_xmin_xmax, xlabel='x [m]', ylabel='V(x) [kN]')

# %%
plot(M, x_xmin_xmax, xlabel='x [m]', ylabel='M(x) [kN-m]')

# %%
plot(dvdx, x_xmin_xmax, xlabel='x [m]', ylabel=r'$\frac{\operatorname{d} v(x)}{\operatorname{d} x}$ [rad]')

# %%
plot(v, x_xmin_xmax, xlabel='x [m]', ylabel='v(x) [m]')

# %% [markdown]
# ### Se calculan las reacciones en la viga

# %% [markdown]
# Reacción vertical en $x=0$ m:

# %%
print(f"Ry(x=0) = {float(+V.subs(x, 0))} kN")
# Out:
# Ry(x=0) = 7.666666666666667 kN

# %% [markdown]
# Reacción vertical en $x=L=6$ m:

# %%
print(f"Ry(x=6) = {float(-V.subs(x, 6-0.001))} kN")
# Out:
# Ry(x=6) = 6.333333333333333 kN
